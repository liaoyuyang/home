# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('/home/future_commodity')
import pandas as pd
import numpy as np
np.seterr(all='ignore')
import lightgbm as lgb
from pathlib import Path
import os
from typing import List, Tuple
import function_future.pre_train as pt
import function_future.train_model as tm
import function_future.FactorFilter as FF
import function_future.backtest_v3 as bv
import function_future.DataLoader as DL, function_future.date_selection as DS
import function_future.trading_visualization as TV
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from joblib import Parallel, delayed
import re

# %%
symbol = 'EB'
train_label = 5
train_end_date = '2025-07-01'

folder_name = f'{symbol}_pred{train_label}_{train_end_date}_v0'

rtn_mul = 1
config_loader = DL.InstrumentConfig()
config_loader.get_instrument_config(symbol)
# Out:
# {'symbol': 'EB',
#  'contract_multiplier': 5,
#  'price_tick': 1,
#  'margin_rate': 0.07,
#  'fee': 3,
#  'fee_way': 'number',
#  'fee_comment': '无',
#  'trading_hours': ['09:00-11:30', '13:30-15:00', '21:00-23:00'],
#  'light': 1,
#  'night': 1,
#  'exchange': 'dce',
#  'name': '苯乙烯'}

# %%
fac_df = pd.read_feather(f'/mnt/Data/writable/liaoyuyang/factor/{symbol}/all_fac/all_factor.feather').set_index(['datetime']).loc[:train_end_date]
fac_df = config_loader.df_cut_time(fac_df, config_loader.get_instrument_config(symbol)['trading_hours'], 10)

exclude_factors = [
        'datetime', 'instrument',
        ]

factor_col = [x for x in fac_df.columns if x not in exclude_factors]

main_fac_piv = fac_df[factor_col]
rtn_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/data/1min/active/main_{symbol}.csv', index_col=0, parse_dates=['ts']).set_index('ts').reindex(index=fac_df.index)
main_fac_piv['pred_ret'] = rtn_df[f'rtn_{train_label}']
main_fac_piv = main_fac_piv.replace([np.inf, -np.inf], np.nan)
main_fac_piv['hour'] = main_fac_piv.index.hour

main_fac_piv['pred_ret'].hist(bins=100, figsize=(8, 3), alpha=0.7, color='blue')
plt.grid(True, alpha=0.3)
plt.show()

pretrainer = pt.Pretrainer(symbol, main_fac_piv, train_end_date, train_label=train_label)

importance = pretrainer.run_full_pretraining(type_lgb = 'reg')
# Out:
# Warning: 发现 1 列全为 NaN，将被剔除: ['FAC_Depth_Reversal_downmean']
#
# Fold 1/5
# Fold 1 验证集日期范围: 2021-02-02 09:11:00 至 2021-12-21 14:46:00
# Fold 1 训练集样本数: 254775, 验证集样本数: 63694
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's l2: 0.991943
# [200]	valid_0's l2: 0.991844
# [300]	valid_0's l2: 0.991803
# [400]	valid_0's l2: 0.991849
# [500]	valid_0's l2: 0.991873
# [600]	valid_0's l2: 0.991911
# [700]	valid_0's l2: 0.99195
# [800]	valid_0's l2: 0.991986
# Early stopping, best iteration is:
# [303]	valid_0's l2: 0.991798
# valid ic: 0.02004218464077114
# 模型最佳迭代次数 = 303
#
# Fold 2/5
# Fold 2 验证集日期范围: 2021-12-21 14:47:00 至 2022-11-10 09:59:00
# Fold 2 训练集样本数: 254775, 验证集样本数: 63694
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's l2: 0.992053
# [200]	valid_0's l2: 0.991895
# [300]	valid_0's l2: 0.991747
# [400]	valid_0's l2: 0.991642
# [500]	valid_0's l2: 0.991586
# [600]	valid_0's l2: 0.991518
# [700]	valid_0's l2: 0.991496
# [800]	valid_0's l2: 0.991462
# [900]	valid_0's l2: 0.991442
# [1000]	valid_0's l2: 0.991424
# [1100]	valid_0's l2: 0.991426
# [1200]	valid_0's l2: 0.99146
# [1300]	valid_0's l2: 0.991476
# [1400]	valid_0's l2: 0.991507
# Early stopping, best iteration is:
# [952]	valid_0's l2: 0.991411
# valid ic: 0.03396596122904729
# 模型最佳迭代次数 = 952
#
# Fold 3/5
# Fold 3 验证集日期范围: 2022-11-10 10:00:00 至 2023-09-21 21:59:00
# Fold 3 训练集样本数: 254775, 验证集样本数: 63694
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's l2: 0.991947
# [200]	valid_0's l2: 0.991944
# [300]	valid_0's l2: 0.991959
# [400]	valid_0's l2: 0.99195
# [500]	valid_0's l2: 0.991948
# [600]	valid_0's l2: 0.991986
# Early stopping, best iteration is:
# [120]	valid_0's l2: 0.99194
# valid ic: 0.008115660354103188
# 模型最佳迭代次数 = 120
#
# Fold 4/5
# Fold 4 验证集日期范围: 2023-09-21 22:00:00 至 2024-08-12 09:12:00
# Fold 4 训练集样本数: 254775, 验证集样本数: 63694
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's l2: 0.99232
# [200]	valid_0's l2: 0.992289
# [300]	valid_0's l2: 0.99227
# [400]	valid_0's l2: 0.992241
# [500]	valid_0's l2: 0.992211
# [600]	valid_0's l2: 0.992186
# [700]	valid_0's l2: 0.992178
# [800]	valid_0's l2: 0.992155
# [900]	valid_0's l2: 0.992136
# [1000]	valid_0's l2: 0.992125
# [1100]	valid_0's l2: 0.992102
# [1200]	valid_0's l2: 0.992094
# [1300]	valid_0's l2: 0.992086
# [1400]	valid_0's l2: 0.992054
# [1500]	valid_0's l2: 0.992051
# [1600]	valid_0's l2: 0.992035
# [1700]	valid_0's l2: 0.992011
# [1800]	valid_0's l2: 0.991997
# [1900]	valid_0's l2: 0.991988
# [2000]	valid_0's l2: 0.991976
# [2100]	valid_0's l2: 0.991963
# [2200]	valid_0's l2: 0.991948
# [2300]	valid_0's l2: 0.991947
# [2400]	valid_0's l2: 0.991915
# [2500]	valid_0's l2: 0.991901
# [2600]	valid_0's l2: 0.991884
# [2700]	valid_0's l2: 0.99187
# [2800]	valid_0's l2: 0.991866
# [2900]	valid_0's l2: 0.991865
# [3000]	valid_0's l2: 0.991855
# [3100]	valid_0's l2: 0.99185
# [3200]	valid_0's l2: 0.991847
# [3300]	valid_0's l2: 0.991852
# [3400]	valid_0's l2: 0.991854
# [3500]	valid_0's l2: 0.991848
# [3600]	valid_0's l2: 0.991828
# [3700]	valid_0's l2: 0.99182
# [3800]	valid_0's l2: 0.991808
# [3900]	valid_0's l2: 0.991804
# [4000]	valid_0's l2: 0.991802
# [4100]	valid_0's l2: 0.9918
# [4200]	valid_0's l2: 0.991792
# [4300]	valid_0's l2: 0.991798
# [4400]	valid_0's l2: 0.991787
# [4500]	valid_0's l2: 0.991783
# [4600]	valid_0's l2: 0.99179
# [4700]	valid_0's l2: 0.991785
# [4800]	valid_0's l2: 0.991785
# [4900]	valid_0's l2: 0.991786
# [5000]	valid_0's l2: 0.991783
# Early stopping, best iteration is:
# [4533]	valid_0's l2: 0.991778
# valid ic: 0.025027145636723577
# 模型最佳迭代次数 = 4533
#
# Fold 5/5
# Fold 5 验证集日期范围: 2024-08-12 09:13:00 至 2025-07-01 22:49:00
# Fold 5 训练集样本数: 254776, 验证集样本数: 63693
# Training until validation scores don't improve for 500 rounds
# [100]	valid_0's l2: 0.992326
# [200]	valid_0's l2: 0.992279
# [300]	valid_0's l2: 0.992247
# [400]	valid_0's l2: 0.992214
# [500]	valid_0's l2: 0.99219
# [600]	valid_0's l2: 0.992166
# [700]	valid_0's l2: 0.99215
# [800]	valid_0's l2: 0.992124
# [900]	valid_0's l2: 0.992106
# [1000]	valid_0's l2: 0.992112
# [1100]	valid_0's l2: 0.992104
# [1200]	valid_0's l2: 0.99209
# [1300]	valid_0's l2: 0.9921
# [1400]	valid_0's l2: 0.992089
# [1500]	valid_0's l2: 0.992077
# [1600]	valid_0's l2: 0.992068
# [1700]	valid_0's l2: 0.992078
# [1800]	valid_0's l2: 0.992074
# [1900]	valid_0's l2: 0.992078
# [2000]	valid_0's l2: 0.992082
# [2100]	valid_0's l2: 0.992067
# Early stopping, best iteration is:
# [1640]	valid_0's l2: 0.992062
# valid ic: 0.022630606036918518
# 模型最佳迭代次数 = 1640
# 特征重要性已保存到 /mnt/Data/writable/liaoyuyang/factor_eval_commodity/2025-07-01/importance/2025-07-01_EB_5_feature_importance_reg.csv
# 特征相关系数表已保存到 /mnt/Data/writable/liaoyuyang/factor_eval_commodity/2025-07-01/correlation/2025-07-01_EB_5_feature_corr.csv
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 因子组别表已保存到 /mnt/Data/writable/liaoyuyang/factor_eval_commodity/2025-07-01/group/2025-07-01_EB_5_feature_group.csv
# 最后两列 Index(['pred_ret', 'hour'], dtype='object')

# %%
factor_info = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/{symbol}_single_factor_eval_{train_label}.csv', index_col=0)
importance_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/importance/{train_end_date}_{symbol}_{train_label}_feature_importance_reg.csv')
corr_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/correlation/{train_end_date}_{symbol}_{train_label}_feature_corr.csv', index_col=0)
group_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/group/{train_end_date}_{symbol}_{train_label}_feature_group.csv')
factor_to_choose = main_fac_piv.columns[:-1]

factor_filter = FF.FactorFilter(importance_df, corr_df, group_df, factor_info, factor_to_choose)
print([x for x in factor_filter.factor_to_choose if x not in factor_info.index])
params = {
    "info_select_params": {"nan_rate": 0.8, "mode_rate": 0.9},
    "importance_select_by_group_params" : {"cut_num_1": 300, "cut_num_2":200, "same_name_cut": 5}, 
    "corr_select_params": {"feature_num_limit": 300, "corr_limit": 0.9}, 
    "sp_select": {"th":0.5},
    "day_cut": {"num_limit":5},
    "exclude_factors": [
            'datetime', 'instrument',
            'JC1D', 'ZCpriceinterval', 'ptvol5',
            'JC2H'
            ]
}
factor_filter.run_selection(**params)

lst1 = [x for x in factor_filter.factor_to_choose if x.startswith('FAC')]
lst2 = [x for x in factor_filter.factor_to_choose if x.startswith('STK')]
lst3 = [x for x in factor_filter.factor_to_choose if re.match(r'^(_RU|_BR|_NR|_L|_TA|_PF|_V|_EG|_MA|_PP|_EB|_UR|_SA|_SH|_PX|_PR|RU_|BR_|NR_|L_|TA_|PF_|V_|EG_|MA_|PP_|EB_|UR_|SA_|SH_|PX_|PR_)', x)]
lst4 = [x for x in factor_filter.factor_to_choose if x not in lst1+lst2+lst3]
len(lst1), len(lst2), len(lst3), len(lst4)
# Out:
# ['FAC_Depth_Reversal_downmean', 'pred_ret']
# 特征分布性过滤：
# 筛选之前因子数量：1927， 筛选之后因子数量：1867
#
# 特征重要性过滤： 300 200 	待筛因子个数 1867
# 无向因子有效个数： 1009 有向因子有效个数： 898
#   选择有向特征 232 个，重要性范围: 1811.00 - 39.00
#   选择无向特征 122 个，重要性范围: 2943.00 - 81.00
#
# 单因子sharpe过滤： 0.5 sp范围-6.038 ~ 6.0977   待筛因子个数 354
#
# 特征相关性性过滤： 300     待筛因子个数 278
#   选择特征 220 个, 特征最大相关性0.8988265098952729
#
# 已挑选日频开盘因子数量： 6 ['day_jump', 'day_first10colarrate', 'day_first4redcorr', 'day_first4greencorr', 'day_first3power', 'day_first10rev']
#
# 保留日频开盘因子数量： 5 ['day_jump', 'day_first10colarrate', 'day_first4redcorr', 'day_first4greencorr', 'day_first3power']
#
# 排除指定因子后，剩余特征 217 个
# (126, 0, 66, 25)

# %%
analyzer = tm.TimeSeriesAnalyzer(
    symbol = symbol,
    factor_col = factor_filter.factor_to_choose,
    train_end_date = train_end_date,
    config_loader = config_loader
)
analyzer.load_and_prepare_data(log_rtn=True, set_category_col=['hour'], label_col=f'rtn_{train_label}', cut=True)
trainer = tm.LGBMTrainer(analyzer)
_ = trainer.train_kfold_v0(custom_params={'verbose':-1}, model_folder_name=folder_name, plot_train=True, n_splits=5)
# Out:
# 正在从 /mnt/Data/writable/liaoyuyang/factor/EB/all_fac/all_factor.feather 加载数据...
# 训练数据加载完成，形状: (318166, 1931)
# 训练集时间范围: 2021-02-02 09:11:00 至 2025-06-30 22:49:00
# [200]	valid_0's rmse: 0.995879
# [400]	valid_0's rmse: 0.995956
# [600]	valid_0's rmse: 0.996107
# {'train_rmse': np.float64(0.9974298296913017), 'val_rmse': np.float64(0.9998071187690113), 'best_iteration': 239}
# test_corr: 0.0080
# [200]	valid_0's rmse: 0.995798
# [400]	valid_0's rmse: 0.995761
# [600]	valid_0's rmse: 0.995891
# [800]	valid_0's rmse: 0.996094
# {'train_rmse': np.float64(0.9957628729540438), 'val_rmse': np.float64(0.9996296132588176), 'best_iteration': 302}
# test_corr: 0.0127
# [200]	valid_0's rmse: 0.995871
# [400]	valid_0's rmse: 0.995911
# [600]	valid_0's rmse: 0.995956
# {'train_rmse': np.float64(0.9969429877075319), 'val_rmse': np.float64(0.9998985174995961), 'best_iteration': 200}
# test_corr: 0.0022
# [200]	valid_0's rmse: 0.996041
# [400]	valid_0's rmse: 0.995996
# [600]	valid_0's rmse: 0.995968
# [800]	valid_0's rmse: 0.995962
# [1000]	valid_0's rmse: 0.995941
# [1200]	valid_0's rmse: 0.995933
# [1400]	valid_0's rmse: 0.995937
# [1600]	valid_0's rmse: 0.995927
# [1800]	valid_0's rmse: 0.995919
# [2000]	valid_0's rmse: 0.995921
# [2200]	valid_0's rmse: 0.99591
# {'train_rmse': np.float64(0.982451457196677), 'val_rmse': np.float64(0.9997032154900407), 'best_iteration': 1870}
# test_corr: 0.0154
# [200]	valid_0's rmse: 0.996062
# [400]	valid_0's rmse: 0.996054
# [600]	valid_0's rmse: 0.996072
# [800]	valid_0's rmse: 0.996127
# {'train_rmse': np.float64(0.995839203362751), 'val_rmse': np.float64(0.9999069694095069), 'best_iteration': 308}
# test_corr: 0.0149

# %%
config = bv.load_config(r"/mnt/Data/writable/liaoyuyang/backtest/backtest_config.json")
config['MODEL_DIR'] = Path(config['MODEL_DIR']) / str(folder_name)
config
# Out:
# {'MODEL_DIR': PosixPath('/mnt/Data/writable/liaoyuyang/model/lightgbm/KFoldModel/models/EB_pred5_2025-07-01_v0'),
#  'OUTPUT_DIR': '/mnt/Data/writable/liaoyuyang/backtest/results',
#  'pic_dir': '/mnt/Data/writable/liaoyuyang/backtest/pic',
#  'feature_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/features',
#  'pred_label_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/predictions',
#  'merged_output_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/merged',
#  'start_date': '20180101',
#  'end_date': '20260101',
#  'ts_col': 'datetime',
#  'instrument_col': 'instrument',
#  'target_col': 'pred_ret',
#  'holding_price_col': 'close',
#  'trading_price_col': 'tick6t60avg',
#  'pos_col': 'pos',
#  'category_col': ['hour'],
#  'factor_col': 'factor',
#  'filter_dict': {'exclude_night': True},
#  'auto_create_dirs': True}

# %%
bt = bv.ModelBacktester(train_end_date, config)
bt.load_config(symbol)
bt.window_end = '2027-01-01'
bt.money = 2_000_000 
bt.fee = 0

bt.load_factor(symbol, end_date=bt.window_end)
bt.load_mktdata(symbol, end_date=bt.window_end)
bt.load_models()
bt.generate_predictions()
pred = bt.combine_models('best_iteration_log_weighted', avg=True)

# %%
merged_data = bt.backtest(th1=0.8, th2=0.5, save=False, open_drop=True, holding_bars=10,
                           day=5*345, model_name='best_iteration_log_weighted', v=2
                        )
# Out:
# trading_hours ['09:00-11:30', '13:30-15:00', '21:00-23:00']
#   0%|          | 0/52874 [00:00<?, ?it/s]

# %%
fig = bv.plot_group_bar(merged_data, periods=[1,5], trading_hours=["09:00-11:30", "13:30-15:00", "21:00-01:00"], g=21)

# %%
bv.analyze_pos_distribution(merged_data)
# Out:
#                       统计值
# 多头(+1) 数量           17286
# 空头(-1) 数量           13521
# 空仓(0) 数量            22069
# 多头占比               32.69%
# 空头占比               25.57%
# 空仓占比               41.74%
# 交易日数量                 155
# 总收益(非年化%)            3.32
# 总交易次数（开平算一次）         2450
# 日均交易次数（开平算一次）       15.81
# 每笔收益(%%)             0.14
# 年化日度夏普               2.50
# 最大回撤(%)             -1.12
# 年化卡玛比率               4.87
# 最赚钱的一天         2026-01-22
# 最亏钱的一天         2026-01-16

# %%
fig = bv.plot_eval(symbol, merged_data, "无")

# %%
tvp = TV.TradingVisualizationPager(symbol=symbol, data = merged_data, skip_weekends=True)
tvp.run()
# Out:
# HBox(children=(Button(description='← 上一交易日', layout=Layout(width='120px'), style=ButtonStyle()), Label(value='…
# Output()
# ✅ 交易可视化工具已启动
# 📈 品种: EB
# 📅 总交易日数: 154
# 📊 总数据点: 55902
# 🎯 使用导航按钮或输入页码进行浏览

# %%
bv.plot_yearly_eval(merged_data)
