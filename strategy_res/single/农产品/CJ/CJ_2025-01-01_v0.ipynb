# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('/home/future_commodity')
import pandas as pd
import numpy as np
np.seterr(all='ignore')
import lightgbm as lgb
from pathlib import Path
import os
from typing import List, Tuple
import function_future.pre_train as pt
import function_future.train_model as tm
import function_future.FactorFilter as FF
import function_future.backtest_v3 as bv
import function_future.DataLoader as DL, function_future.date_selection as DS
import function_future.trading_visualization as TV
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from joblib import Parallel, delayed
import re

# %%
symbol = 'CJ'
train_label = 5
train_end_date = '2025-01-01'

folder_name = f'{symbol}_pred{train_label}_{train_end_date}_v0'

rtn_mul = 1
config_loader = DL.InstrumentConfig()
config_loader.get_instrument_config(symbol)
# Out:
# {'symbol': 'CJ',
#  'contract_multiplier': 5,
#  'price_tick': 5,
#  'margin_rate': 0.1,
#  'fee': 0.0,
#  'fee_way': 'number',
#  'fee_comment': '平今',
#  'trading_hours': ['09:00-11:30', '13:30-15:00'],
#  'light': 1,
#  'night': 0,
#  'exchange': 'czce',
#  'name': '红枣'}

# %%
fac_df = pd.read_feather(f'/mnt/Data/writable/liaoyuyang/factor/{symbol}/all_fac/all_factor.feather').set_index(['datetime']).loc[:train_end_date]
fac_df = config_loader.df_cut_time(fac_df, config_loader.get_instrument_config(symbol)['trading_hours'], 10)

exclude_factors = [
        'datetime', 'instrument',
        ]

factor_col = [x for x in fac_df.columns if x not in exclude_factors]

main_fac_piv = fac_df[factor_col]
rtn_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/data/1min/active/main_{symbol}.csv', index_col=0, parse_dates=['ts']).set_index('ts').reindex(index=fac_df.index)
main_fac_piv['pred_ret'] = rtn_df[f'rtn_{train_label}']
main_fac_piv = main_fac_piv.replace([np.inf, -np.inf], np.nan)
main_fac_piv['hour'] = main_fac_piv.index.hour

main_fac_piv['pred_ret'].hist(bins=100, figsize=(8, 3), alpha=0.7, color='blue')
plt.grid(True, alpha=0.3)
plt.show()

pretrainer = pt.Pretrainer(symbol, main_fac_piv, train_end_date, train_label=train_label)

importance = pretrainer.run_full_pretraining(type_lgb = 'reg')
# Out:
# 2025-01-01_CJ_5

# %%
factor_info = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/{symbol}_single_factor_eval_{train_label}.csv', index_col=0)
importance_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/importance/{train_end_date}_{symbol}_{train_label}_feature_importance_reg.csv')
corr_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/correlation/{train_end_date}_{symbol}_{train_label}_feature_corr.csv', index_col=0)
group_df = pd.read_csv(f'/mnt/Data/writable/liaoyuyang/factor_eval_commodity/{train_end_date}/group/{train_end_date}_{symbol}_{train_label}_feature_group.csv')
factor_to_choose = main_fac_piv.columns[:-1]

factor_filter = FF.FactorFilter(importance_df, corr_df, group_df, factor_info, factor_to_choose)
print([x for x in factor_filter.factor_to_choose if x not in factor_info.index])
params = {
    "info_select_params": {"nan_rate": 0.8, "mode_rate": 0.9},
    "importance_select_by_group_params" : {"cut_num_1": 300, "cut_num_2":200, "same_name_cut": 5}, 
    "corr_select_params": {"feature_num_limit": 300, "corr_limit": 0.9}, 
    "sp_select": {"th":0.5},
    "day_cut": {"num_limit":5},
    "exclude_factors": [
            'datetime', 'instrument',
            'JC1D', 'ZCpriceinterval', 'ptvol5',
            'JC2H'
            ]
}
factor_filter.run_selection(**params)

lst1 = [x for x in factor_filter.factor_to_choose if x.startswith('FAC')]
lst2 = [x for x in factor_filter.factor_to_choose if x.startswith('STK')]
lst3 = [x for x in factor_filter.factor_to_choose if re.match(r'^(_C|_CS|_RR|_JD|_LH|_AP|_CJ|_SR|_CF|_CY|C_|CS_|RR_|JD_|LH_|AP_|CJ_|SR_|CF_|CY_)', x)]
lst4 = [x for x in factor_filter.factor_to_choose if x not in lst1+lst2+lst3]
len(lst1), len(lst2), len(lst3), len(lst4)
# Out:
# ['pred_ret']
# 特征分布性过滤：
# 筛选之前因子数量：1885， 筛选之后因子数量：1813
#
# 特征重要性过滤： 300 200 	待筛因子个数 1813
# 无向因子有效个数： 850 有向因子有效个数： 1015
#   选择有向特征 247 个，重要性范围: 2546.00 - 81.00
#   选择无向特征 145 个，重要性范围: 4445.00 - 171.00
#
# 单因子sharpe过滤： 0.5 sp范围-16.1044 ~ 11.9218   待筛因子个数 392
#
# 特征相关性性过滤： 300     待筛因子个数 355
#   选择特征 300 个, 特征最大相关性0.8965756921689322
#
# 已挑选日频开盘因子数量： 3 ['day_first3power', 'day_first4greencorr', 'day_first10colarrate']
#
# 排除指定因子后，剩余特征 297 个
# (225, 0, 52, 20)

# %%
analyzer = tm.TimeSeriesAnalyzer(
    symbol = symbol,
    factor_col = factor_filter.factor_to_choose,
    train_end_date = train_end_date,
    config_loader = config_loader
)
analyzer.load_and_prepare_data(log_rtn=True, set_category_col=['hour'], label_col=f'rtn_{train_label}', cut=True)
trainer = tm.LGBMTrainer(analyzer)
_ = trainer.train_kfold_v0(custom_params={'verbose':-1}, model_folder_name=folder_name, plot_train=True, n_splits=5)
# Out:
# 正在从 /mnt/Data/writable/liaoyuyang/factor/CJ/all_fac/all_factor.feather 加载数据...
# 训练数据加载完成，形状: (192206, 1889)
# 训练集时间范围: 2021-02-01 09:11:00 至 2024-12-31 14:49:00
# [200]	valid_0's rmse: 0.98929
# [400]	valid_0's rmse: 0.98909
# [600]	valid_0's rmse: 0.98908
# [800]	valid_0's rmse: 0.989138
# {'train_rmse': np.float64(0.9908843509790164), 'val_rmse': np.float64(0.9988558464732619), 'best_iteration': 475}
# test_corr: 0.0006
# [200]	valid_0's rmse: 0.938181
# [400]	valid_0's rmse: 0.937703
# [600]	valid_0's rmse: 0.937373
# [800]	valid_0's rmse: 0.93733
# [1000]	valid_0's rmse: 0.937213
# [1200]	valid_0's rmse: 0.937152
# [1400]	valid_0's rmse: 0.937205
# [1600]	valid_0's rmse: 0.937401
# {'train_rmse': np.float64(0.9803377614967549), 'val_rmse': np.float64(0.9975694633368074), 'best_iteration': 1199}
# test_corr: -0.0037
# [200]	valid_0's rmse: 0.926718
# [400]	valid_0's rmse: 0.926353
# [600]	valid_0's rmse: 0.926155
# [800]	valid_0's rmse: 0.926011
# [1000]	valid_0's rmse: 0.92593
# [1200]	valid_0's rmse: 0.925901
# [1400]	valid_0's rmse: 0.925888
# [1600]	valid_0's rmse: 0.925905
# [1800]	valid_0's rmse: 0.925895
# {'train_rmse': np.float64(0.9783182192253669), 'val_rmse': np.float64(0.9979372198613246), 'best_iteration': 1360}
# test_corr: -0.0031
# [200]	valid_0's rmse: 0.990317
# [400]	valid_0's rmse: 0.989685
# [600]	valid_0's rmse: 0.989463
# [800]	valid_0's rmse: 0.989333
# [1000]	valid_0's rmse: 0.989219
# [1200]	valid_0's rmse: 0.989125
# [1400]	valid_0's rmse: 0.98909
# [1600]	valid_0's rmse: 0.989073
# [1800]	valid_0's rmse: 0.989107
# {'train_rmse': np.float64(0.9757656219410077), 'val_rmse': np.float64(0.9973935654690926), 'best_iteration': 1499}
# test_corr: -0.0087
# [200]	valid_0's rmse: 0.992832
# [400]	valid_0's rmse: 0.992539
# [600]	valid_0's rmse: 0.992395
# [800]	valid_0's rmse: 0.992307
# [1000]	valid_0's rmse: 0.992347
# [1200]	valid_0's rmse: 0.992363
# {'train_rmse': np.float64(0.9847495746414158), 'val_rmse': np.float64(0.9986024128357995), 'best_iteration': 795}
# test_corr: 0.0007

# %%
config = bv.load_config(r"/mnt/Data/writable/liaoyuyang/backtest/backtest_config.json")
config['MODEL_DIR'] = Path(config['MODEL_DIR']) / str(folder_name)
config
# Out:
# {'MODEL_DIR': PosixPath('/mnt/Data/writable/liaoyuyang/model/lightgbm/KFoldModel/models/CJ_pred5_2025-01-01_v0'),
#  'OUTPUT_DIR': '/mnt/Data/writable/liaoyuyang/backtest/results',
#  'pic_dir': '/mnt/Data/writable/liaoyuyang/backtest/pic',
#  'feature_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/features',
#  'pred_label_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/predictions',
#  'merged_output_dir': '/mnt/Data/writable/liaoyuyang/backtest/data/merged',
#  'start_date': '20180101',
#  'end_date': '20260101',
#  'ts_col': 'datetime',
#  'instrument_col': 'instrument',
#  'target_col': 'pred_ret',
#  'holding_price_col': 'close',
#  'trading_price_col': 'tick6t60avg',
#  'pos_col': 'pos',
#  'category_col': ['hour'],
#  'factor_col': 'factor',
#  'filter_dict': {'exclude_night': True},
#  'auto_create_dirs': True}

# %%
bt = bv.ModelBacktester(train_end_date, config)
bt.load_config(symbol)
bt.window_end = '2027-01-01'
bt.money = 2_000_000 
bt.fee = 0

bt.load_factor(symbol, end_date=bt.window_end)
bt.load_mktdata(symbol, end_date=bt.window_end)
bt.load_models()
bt.generate_predictions()
pred = bt.combine_models('best_iteration_log_weighted', avg=True)

# %%
bt.mkt_data
# Out:
#                    datetime instrument     open     high      low    close  \
# 0       2021-02-01 09:01:00      CJ105  10255.0  10255.0  10220.0  10235.0
# 1       2021-02-01 09:02:00      CJ105  10230.0  10240.0  10225.0  10240.0
# 2       2021-02-01 09:03:00      CJ105  10240.0  10245.0  10230.0  10245.0
# 3       2021-02-01 09:04:00      CJ105  10245.0  10250.0  10235.0  10245.0
# 4       2021-02-01 09:05:00      CJ105  10245.0  10245.0  10235.0  10240.0
# ...                     ...        ...      ...      ...      ...      ...
# 275311  2026-03-06 14:56:00      CJ605   9025.0   9030.0   9020.0   9020.0
# 275312  2026-03-06 14:57:00      CJ605   9020.0   9030.0   9020.0   9030.0
# 275313  2026-03-06 14:58:00      CJ605   9030.0   9030.0   9020.0   9025.0
# 275314  2026-03-06 14:59:00      CJ605   9020.0   9030.0   9020.0   9020.0
# 275315  2026-03-06 15:00:00      CJ605   9030.0   9030.0   9020.0   9025.0
#
#            last_twap     mid_price  volume    turnover  ...    spread  \
# 0       10234.888889  10235.692356   436.0  22318050.0  ...  5.800000
# 1       10230.747126  10231.436983   180.0   9207800.0  ...  5.114943
# 2       10236.134752  10236.497322    31.0   1586500.0  ...  5.354610
# 3       10240.669291  10240.905401    63.0   3226250.0  ...  5.157480
# 4       10240.363636  10241.196852    55.0   2816200.0  ...  5.318182
# ...              ...           ...     ...         ...  ...       ...
# 275311   9026.754808   9025.308351   664.0  29965850.0  ...  5.168269
# 275312   9027.297297   9026.428113   455.0  20536625.0  ...  5.000000
# 275313   9024.756098   9025.288687   505.0  22789950.0  ...  5.097561
# 275314   9022.974359   9023.955285   550.0  24816700.0  ...  5.076923
# 275315   9024.976959   9024.393814  1110.0  50089700.0  ...  5.184332
#
#         bar_count  trade_date  tick10avg   tick0t10avg   tick6t15avg  \
# 0             415  2021-02-01   10248.75  10245.119048  10243.717949
# 1             271  2021-02-01   10230.75  10230.000000  10229.375000
# 2             201  2021-02-01   10237.25  10236.875000  10232.884615
# 3             175  2021-02-01   10240.75  10240.769231  10236.842105
# 4             144  2021-02-01   10242.50  10242.500000  10241.944444
# ...           ...         ...        ...           ...           ...
# 275311        208  2026-03-06    9027.75   9027.209302   9028.918919
# 275312        185  2026-03-06    9022.75   9023.181818   9023.939394
# 275313        205  2026-03-06    9029.25   9028.243243   9028.684211
# 275314        195  2026-03-06    9021.50   9021.406250   9022.115385
# 275315        217  2026-03-06    9025.25   9025.405405   9025.000000
#
#          tick6t60avg     rtn_1     rtn_5    rtn_10
# 0       10233.514851  0.000506 -0.003540 -0.003703
# 1       10230.605096  0.000466 -0.002990 -0.003182
# 2       10235.781250 -0.000054 -0.003042 -0.001108
# 3       10240.550459 -0.002079 -0.003530 -0.002329
# 4       10240.000000 -0.002380 -0.007068 -0.000759
# ...              ...       ...       ...       ...
# 275311   9026.793478 -0.000354  0.003268  0.012523
# 275312   9027.604790 -0.000148  0.008263  0.013539
# 275313   9024.411765  0.000213  0.013818  0.013646
# 275314   9023.074713  0.006553  0.014245  0.011330
# 275315   9025.000000 -0.002976  0.009011  0.007024
#
# [275316 rows x 23 columns]

# %%
merged_data = bt.backtest(th1=0.9, th2=0.5, save=False, open_drop=True, holding_bars=10,
                           day=5*345, model_name='best_iteration_log_weighted', v=2
                        )
# Out:
# trading_hours ['09:00-11:30', '13:30-15:00']
#   0%|          | 0/50623 [00:00<?, ?it/s]

# %%
fig = bv.plot_group_bar(merged_data, periods=[1,5], trading_hours=["09:00-11:30", "13:30-15:00", "21:00-01:00"], g=21)

# %%
bv.analyze_pos_distribution(merged_data)
# Out:
#                       统计值
# 多头(+1) 数量            9884
# 空头(-1) 数量           10833
# 空仓(0) 数量            29908
# 多头占比               19.52%
# 空头占比               21.40%
# 空仓占比               59.08%
# 交易日数量                 225
# 总收益(非年化%)            0.36
# 总交易次数（开平算一次）         2171
# 日均交易次数（开平算一次）        9.65
# 每笔收益(%%)             0.02
# 年化日度夏普               0.13
# 最大回撤(%)             -2.99
# 年化卡玛比率               0.13
# 最赚钱的一天         2025-09-18
# 最亏钱的一天         2025-09-25

# %%
fig = bv.plot_eval(symbol, merged_data, "无")

# %%
tvp = TV.TradingVisualizationPager(symbol=symbol, data = merged_data, skip_weekends=True)
tvp.run()
# Out:
# HBox(children=(Button(description='← 上一交易日', layout=Layout(width='120px'), style=ButtonStyle()), Label(value='…
# Output()
# ✅ 交易可视化工具已启动
# 📈 品种: CJ
# 📅 总交易日数: 225
# 📊 总数据点: 54450
# 🎯 使用导航按钮或输入页码进行浏览

# %%
bv.plot_yearly_eval(merged_data)
